# %%
import pandas as pd
import numpy as np

# %%
# Convert cleaned_postings
df = pd.read_csv("C:/Users/punit/OneDrive/Documents/Job_market_intelligence_project/data/cleaned_postings.csv")
df_slim = df[["job_id", "title", "company_name", "clean_location",
              "normalized_salary", "formatted_experience_level",
              "formatted_work_type", "remote_allowed"]]

df_slim.to_parquet("C:/Users/punit/OneDrive/Documents/Job_market_intelligence_project/data/cleaned_postings.parquet", index=False)

# Convert job_skills
skills_df = pd.read_csv("C:/Users/punit/OneDrive/Documents/Job_market_intelligence_project/data/job_skills_clean.csv")
skills_slim = skills_df[["job_id", "title", "skill_name",
                          "normalized_salary", "formatted_experience_level"]]
skills_slim.to_parquet("C:/Users/punit/OneDrive/Documents/Job_market_intelligence_project/data/job_skills.parquet", index=False)

# %%
skills_df.columns
# Out:
# Index(['Unnamed: 0.3', 'Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'job_id',
#        'company_name', 'title', 'description', 'location', 'views',
#        'formatted_work_type', 'applies', 'original_listed_time',
#        'remote_allowed', 'application_type', 'expiry',
#        'formatted_experience_level', 'listed_time', 'work_type',
#        'normalized_salary', 'clean_location', 'skill_abr', 'skill_name'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['job_id', 'company_name', 'title', 'description', 'location', 'views',
#        'formatted_work_type', 'applies', 'original_listed_time',
#        'remote_allowed', 'application_type', 'expiry',
#        'formatted_experience_level', 'listed_time', 'work_type',
#        'normalized_salary', 'clean_location'],
#       dtype='object')
